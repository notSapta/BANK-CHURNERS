# %% [raw]
# DATA ANALYSIS SECTION
# In this section, we will analyze our data using graphs to gain some insights into our dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("D:\BankChurners.csv")
df.head()
# type(df)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %% [raw]
# Let us have a look into the number of columns and the data-type they consist

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %% [raw]
# We shall now start with the data cleaning process

# %%
df = df.drop(['CLIENTNUM'],axis=1)   #deleting the 'CLIENTNUM' Column as it contains irrelevant data to our analysis
df.head()
# df.describe()
# type(df)
# Out:
#       Attrition_Flag  Customer_Age Gender  Dependent_count Education_Level  \
# 0  Existing Customer            45      M                3     High School
# 1  Existing Customer            49      F                5        Graduate
# 2  Existing Customer            51      M                3        Graduate
# 3  Existing Customer            40      F                4     High School
# 4  Existing Customer            40      M                3      Uneducated
#
#   Marital_Status Income_Category Card_Category  Months_on_book  \
# 0        Married     $60K - $80K          Blue              39
# 1         Single  Less than $40K          Blue              44
# 2        Married    $80K - $120K          Blue              36
# 3        Unknown  Less than $40K          Blue              34
# 4        Married     $60K - $80K          Blue              21
#
#    Total_Relationship_Count  ...  Credit_Limit  Total_Revolving_Bal  \
# ...

# %% [raw]
# From this we infer that :
# --> The average age of clients is around 46 years with our youngest clients being 26 years and oldest client being 76 years old.
# --> The average Credit Limit is $8,631.95 with maximum ranging upto $34,516.
# --> Almost 25% of the clients are more than 52 years old.

# %%
df.isnull().sum()
# Out:
# Attrition_Flag                                                                                                                        0
# Customer_Age                                                                                                                          0
# Gender                                                                                                                                0
# Dependent_count                                                                                                                       0
# Education_Level                                                                                                                       0
# Marital_Status                                                                                                                        0
# Income_Category                                                                                                                       0
# ...

# %% [raw]
# Apparently we do not have any NULL values in our dataset.
# Now let's work towards representing our data in a Visually Attractive and easy to understand manner.

# %%
pie_value = df["Attrition_Flag"].value_counts()
c=['yellow','grey']
plt.pie(pie_value, colors=c, labels=pie_value.index,autopct="%1.1f%%" ,shadow=True, explode=[0.1,0],startangle=45)
plt.title("\nCUSTOMER  DISTRIBUTION",fontsize=15, color = 'skyblue', fontweight = 'bold')
print('\nTotal Number Of Customers : ',df['Attrition_Flag'].count())
# Out:
# Total Number Of Customers :  10127

# %%
gen_value = df["Gender"].value_counts()
c=['magenta','cyan']
plt.pie(gen_value, colors=c, labels={'Female','Male'}, autopct="%1.1f%%" ,shadow=True, startangle=45)
plt.title("\nGENDER  DISTRIBUTION",fontsize=15, color = 'skyblue', fontweight = 'bold')
print('\nTotal Number Of Customers : ',df['Attrition_Flag'].count())
# Out:
# Total Number Of Customers :  10127

# %%
income = df.Income_Category.value_counts()
c=['#cca300','#e6b800','#ffd11a','#ffe066','#fff0b3','#fffae6']
plt.pie(income, labels =income.index, autopct = '%1.1f%%',colors=c, shadow = True)
plt.title("\nINCOME DISTRIBUTION", fontsize = 15,color = 'skyblue', fontweight = 'bold')
print('\nTotal number of customers:', df.Income_Category.count())
# Out:
# Total number of customers: 10127

# %%
card = df.Card_Category.value_counts()
c=['#ff4dc4','#ff99dd','#ffb3e6','#ffe6f7']
plt.pie(card, labels=card.index, autopct = '%1.1f%%', colors=c, shadow=True)
plt.title("\nCARD TYPE DISTRIBUTION", fontsize = 15,color = 'skyblue', fontweight = 'bold')
print('\nTotal number of customers:', df.Card_Category.count())
# Out:
# Total number of customers: 10127

# %%
marital = df.Marital_Status.value_counts()
c=['#e6eeff','#80aaff','#99bbff','#ccddff']
plt.pie(marital, labels =marital.index, autopct = '%1.1f%%',colors=c, shadow = True)
plt.title("\nMARITAL STATUS DISTRIBUTION", fontsize = 15,color = 'skyblue', fontweight = 'bold')
print('\nTotal number of customers:', df.Marital_Status.count())
# Out:
# Total number of customers: 10127

# %%
edu_prop=df.Education_Level.value_counts()
c=['#00b33c','#00cc44','#00e64d','#00ff55','#66ff99','#99ffbb','#e6ffee']
plt.pie(edu_prop, labels=edu_prop.index, autopct = "%1.1f%%", colors=c,shadow=True, startangle=0)
plt.title("\nEDUCATION LEVEL DISTRIBUTION",fontsize=15, color = 'skyblue', fontweight = 'bold')
print('\nTotal Number Of Customers : ',df['Education_Level'].count())
# Out:
# Total Number Of Customers :  10127

# %% [raw]
# From these, we infer that:
# --> 16% of customers have attrited.
# --> Almost both genders are equally contributing with a slight more percentages from women.      [ Both Genders have contributed almost equally ]
# --> Most of our customers have an income less than $40K per annum.                               [ Our prices should be affordable ]
# --> Blue Card is used the most by our customers.                                                 [ We should focus on upgrading the facilities of BLUE Card ]
# --> Majorities of our customers are either Single or Married.                                    [ Denotes a stable society customer base ]
# --> Most of our Customers are studying in High Scool or are Graduates.                           [ These people are most prone to Loans ]

# %%
sns.kdeplot(df.Credit_Limit[df.Attrition_Flag=='Existing Customer'], color = 'orange', label='Existing Customer',fill = True, gridsize = 10)
sns.kdeplot(df.Credit_Limit[df.Attrition_Flag=='Attrited Customer'], color = 'magenta', label='Attrited Customer', fill = True, gridsize = 10)
plt.title('\nCREDIT LIMIT\n', fontsize=15, color = 'green', fontweight='bold')
plt.legend()
plt.show()

# %% [raw]
# --> The customers whose credit limit is small (around $2.5K) are more likely to be loyal as they can afford to pay the Amount by next month.
# --> Large Credit Limit reduces our customer base as most people are unable to pay back the debt with high interests.

# %%
sns.kdeplot(df.Total_Trans_Amt[df.Attrition_Flag=='Existing Customer'], color = 'green', label='Existing Customer',fill = True, gridsize = 10)
sns.kdeplot(df.Total_Trans_Amt[df.Attrition_Flag=='Attrited Customer'], color = 'purple', label='Attrited Customer', fill = True, gridsize = 10)
plt.title('\nTOTAL TRANSACTION AMOUNT\n', fontsize=15, color = 'green', fontweight='bold')
plt.legend()
plt.show()

# %% [raw]
# --> Increasing number of Small Transaction Amounts denotes a Customer Base that is transferring funds to another account.
# --> These customers are more prone to leave anytime.

# %%
sns.kdeplot(df.Customer_Age[df.Attrition_Flag=='Existing Customer'], color = 'blue', label='Existing Customer',fill = True, gridsize = 10)
sns.kdeplot(df.Customer_Age[df.Attrition_Flag=='Attrited Customer'], color = 'orange', label='Attrited Customer', fill = True, gridsize = 10)
plt.title('\nCUSTOMER AGE DISTRIBUTION\n', fontsize=15, color = 'green', fontweight='bold')
plt.legend()
plt.show()

# %% [raw]
# --> Most customers who have deserted our services are middle-aged people.
# --> Almost equal ratios have attrited because this (40-50) is the optimal age to balance between money and experience.
# --> It is clear that our main Customer Base is middle-aged citizens.

# %%
sns.kdeplot(df.Months_on_book[df.Attrition_Flag=='Existing Customer'], color = 'blue', label='Existing Customer',fill = True, gridsize = 10)
sns.kdeplot(df.Months_on_book[df.Attrition_Flag=='Attrited Customer'], color = 'orange', label='Attrited Customer', fill = True, gridsize = 10)
plt.title('\nMONTHS ON BOOK\n', fontsize=15, color = 'green', fontweight='bold')
plt.legend()
plt.show()

# %% [raw]
# --> Usually, customers have attrited after 3 years period.
# --> Probably they did not like our services ( found a better deal ).

# %%
sns.kdeplot(df.Total_Relationship_Count[df.Attrition_Flag=='Existing Customer'], color = 'blue', label='Existing Customer',fill = True, gridsize = 10)
sns.kdeplot(df.Total_Relationship_Count[df.Attrition_Flag=='Attrited Customer'], color = 'red', label='Attrited Customer', fill = True, gridsize = 10)
plt.title('\nTOTAL RELATIONSHIP COUNT\n', fontsize=15, color = 'green', fontweight='bold')
plt.legend()
plt.show()

# %% [raw]
# --> The more the number of Relationships, the fewer customers churned away.
# --> Hence, increase in Bank Relationships with customers will increase their loyalty and they won't flee.

# %% [raw]
# <-----------------------------------------------PREDICTION ALGORITHM------------------------------------------------->
#
#
# Here, we use a Classifier Algorithm to classify if the given customer will be an Attrited Customer or not

# %%
pd.set_option('display.max_columns',25)    # Forces HEAD() to display upto 25 columns when not empty
df.head()
# type(df)
# Out:
#       Attrition_Flag  Customer_Age Gender  Dependent_count Education_Level  \
# 0  Existing Customer            45      M                3     High School
# 1  Existing Customer            49      F                5        Graduate
# 2  Existing Customer            51      M                3        Graduate
# 3  Existing Customer            40      F                4     High School
# 4  Existing Customer            40      M                3      Uneducated
#
#   Marital_Status Income_Category Card_Category  Months_on_book  \
# 0        Married     $60K - $80K          Blue              39
# 1         Single  Less than $40K          Blue              44
# 2        Married    $80K - $120K          Blue              36
# 3        Unknown  Less than $40K          Blue              34
# 4        Married     $60K - $80K          Blue              21
#
#    Total_Relationship_Count  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder                           # Here we Encode 'Gender' as (Male=1, Female=0) and 'Marital_Status' as (0=Divorced, 1=Married, 2=Single, 3=Unknown)
le = LabelEncoder()                                                      # Here we use method LabelEncode() as the variables are nominal(order does not matter)
cols = ['Gender','Marital_Status']
df[cols] = df[cols].apply(LabelEncoder().fit_transform)
df.head()
# type(df)
# Out:
#       Attrition_Flag  Customer_Age  Gender  Dependent_count Education_Level  \
# 0  Existing Customer            45       1                3     High School
# 1  Existing Customer            49       0                5        Graduate
# 2  Existing Customer            51       1                3        Graduate
# 3  Existing Customer            40       0                4     High School
# 4  Existing Customer            40       1                3      Uneducated
#
#    Marital_Status Income_Category Card_Category  Months_on_book  \
# 0               1     $60K - $80K          Blue              39
# 1               2  Less than $40K          Blue              44
# 2               1    $80K - $120K          Blue              36
# 3               3  Less than $40K          Blue              34
# 4               1     $60K - $80K          Blue              21
#
#    Total_Relationship_Count  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# ...

# %%
# Here we encode 3 columns : Education_level, Income_Category, Card_Category using ORDINAL ENCODING.
# Unlike Label Encoder, the converted integer value of Ordinal Encoding refers to increasing strength or order.

from sklearn.preprocessing import OrdinalEncoder
Edu = ['Unknown','Uneducated','High School','College','Graduate','Post-Graduate','Doctorate']
Inc = ['Unknown','Less than $40K','$40K - $60K','$60K - $80K','$80K - $120K','$120K +']
Cardc = ['Blue','Silver','Gold','Platinum']
e = OrdinalEncoder(categories=[Edu,Inc,Cardc])
df[['Education_Level','Income_Category','Card_Category']] = e.fit_transform(df[['Education_Level','Income_Category','Card_Category']])
df.head()
# Out:
#       Attrition_Flag  Customer_Age  Gender  Dependent_count  Education_Level  \
# 0  Existing Customer            45       1                3              2.0
# 1  Existing Customer            49       0                5              4.0
# 2  Existing Customer            51       1                3              4.0
# 3  Existing Customer            40       0                4              2.0
# 4  Existing Customer            40       1                3              1.0
#
#    Marital_Status  Income_Category  Card_Category  Months_on_book  \
# 0               1              3.0            0.0              39
# 1               2              1.0            0.0              44
# 2               1              4.0            0.0              36
# 3               3              1.0            0.0              34
# 4               1              3.0            0.0              21
#
#    Total_Relationship_Count  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# ...

# %%
X = df.iloc[:,1:20].values                 #independent variables
y = df.iloc[:,0].values                    #dependent variable

# %%
# Splitting the dataset into Training and Testing Parts

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

# %%
# Feature Scaling all the variables in X

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [raw]
# <-------------------------------------------- MODEL SELECTION --------------------------------------------------------->

# %%
# ALGORITHM 1

from sklearn.tree import DecisionTreeClassifier                                 # Implementing DECISION TREE CLASSIFIER to classify
c = DecisionTreeClassifier(criterion='entropy',random_state=0)                  
c.fit(X_train, y_train)                                                         
y_pred = c.predict(X_test)

from sklearn.metrics import confusion_matrix, accuracy_score                    # Importing library to measure the accuracy of our results 
cm = confusion_matrix(y_test, y_pred)                                           # Making Confusion Matrix
ac1 = accuracy_score(y_test, y_pred)                                             # Making Accuracy score.
print('CONFUSION MATRIX :\n',cm)                                                              # Printing CONFUSION MATRIX
print('\nACCURACY : \n:',ac1*100)                                                       # Printing Model ACCURACY
# Out:
# CONFUSION MATRIX :
#  [[ 243   66]
#  [  53 1664]]
#
# ACCURACY :
# : 94.1263573543929

# %%
# ALGORITHM 2

from sklearn.linear_model import LogisticRegression                             # Implementing Logistic Regression to classify
c = LogisticRegression(random_state=0)                                          
c.fit(X_train, y_train)
y_pred = c.predict(X_test)

from sklearn.metrics import confusion_matrix, accuracy_score                    # Importing library to measure the accuracy of our results 
cm = confusion_matrix(y_test, y_pred)                                           # Making Confusion Matrix
ac2 = accuracy_score(y_test, y_pred)                                             # Making Accuracy score.
print('CONFUSION MATRIX :\n',cm)                                                              # Printing CONFUSION MATRIX
print('\nACCURACY : \n:',ac2*100)                                                       # Printing Model ACCURACY
# Out:
# CONFUSION MATRIX :
#  [[ 182  127]
#  [  63 1654]]
#
# ACCURACY :
# : 90.62191510365251

# %%
# ALGORITHM 3

from sklearn.svm import SVC                                                     # Implementing Support Vector Machine to classify
c = SVC(kernel = 'linear',random_state = 0)
c.fit(X_train, y_train)
y_pred = c.predict(X_test)

from sklearn.metrics import confusion_matrix, accuracy_score                    # Importing library to measure the accuracy of our results 
cm = confusion_matrix(y_test, y_pred)                                           # Making Confusion Matrix
ac3 = accuracy_score(y_test, y_pred)                                             # Making Accuracy score.
print('CONFUSION MATRIX :\n',cm)                                                              # Printing CONFUSION MATRIX
print('\nACCURACY : \n:',ac3*100)                                                       # Printing Model ACCURACY
# Out:
# CONFUSION MATRIX :
#  [[ 181  128]
#  [  66 1651]]
#
# ACCURACY :
# : 90.42448173741361

# %%
# ALGORITHM 4

from sklearn.svm import SVC                                                     # Implementing Kernel Support Vector Machine to classify
c = SVC(kernel = 'rbf', random_state=0)                       
c.fit(X_train, y_train)
y_pred = c.predict(X_test)

from sklearn.metrics import confusion_matrix, accuracy_score                    # Importing library to measure the accuracy of our results 
cm = confusion_matrix(y_test, y_pred)                                           # Making Confusion Matrix
ac4 = accuracy_score(y_test, y_pred)                                             # Making Accuracy score.
print('CONFUSION MATRIX :\n',cm)                                                              # Printing CONFUSION MATRIX
print('\nACCURACY : \n:',ac4*100)                                                       # Printing Model ACCURACY
# Out:
# CONFUSION MATRIX :
#  [[ 213   96]
#  [  40 1677]]
#
# ACCURACY :
# : 93.2872655478776

# %%
# ALGORITHM 5

from sklearn.neighbors import KNeighborsClassifier                              # Implementing K-Nearest Neighbors algorithm to classify
k = KNeighborsClassifier()
k.fit(X_train, y_train)
y_pred = c.predict(X_test)

from sklearn.metrics import confusion_matrix, accuracy_score                    # Importing library to measure the accuracy of our results 
cm = confusion_matrix(y_test, y_pred)                                           # Making Confusion Matrix
ac5 = accuracy_score(y_test, y_pred)                                             # Making Accuracy score.
print('CONFUSION MATRIX :\n',cm)                                                              # Printing CONFUSION MATRIX
print('\nACCURACY : \n:',ac5*100)                                                       # Printing Model ACCURACY
# Out:
# CONFUSION MATRIX :
#  [[ 213   96]
#  [  40 1677]]
#
# ACCURACY :
# : 93.2872655478776

# %%
# ALGORITHM 6

from sklearn.naive_bayes import GaussianNB                                      # Implementing Naive Bayes Classifier to classify
c = GaussianNB()
c.fit(X_train, y_train)
y_pred = c.predict(X_test)

from sklearn.metrics import confusion_matrix, accuracy_score                    # Importing library to measure the accuracy of our results 
cm = confusion_matrix(y_test, y_pred)                                           # Making Confusion Matrix
ac6 = accuracy_score(y_test, y_pred)                                             # Making Accuracy score.
print('CONFUSION MATRIX :\n',cm)                                                              # Printing CONFUSION MATRIX
print('\nACCURACY : \n:',ac6*100)                                                       # Printing Model ACCURACY
# Out:
# CONFUSION MATRIX :
#  [[ 196  113]
#  [ 128 1589]]
#
# ACCURACY :
# : 88.10463968410662

# %%
# ALGORITHM 7

from sklearn.ensemble import RandomForestClassifier                            # Implementing Random Forest Classifier to classify
c = RandomForestClassifier(n_estimators=100, criterion = 'entropy', random_state=0)
c.fit(X_train, y_train)
y_pred = c.predict(X_test)

from sklearn.metrics import confusion_matrix, accuracy_score                    # Importing library to measure the accuracy of our results 
cm = confusion_matrix(y_test, y_pred)                                           # Making Confusion Matrix
ac7 = accuracy_score(y_test, y_pred)                                             # Making Accuracy score.
print('CONFUSION MATRIX :\n',cm)                                                              # Printing CONFUSION MATRIX
print('\nACCURACY : \n:',ac7*100)                                                       # Printing Model ACCURACY
# Out:
# CONFUSION MATRIX :
#  [[ 250   59]
#  [  26 1691]]
#
# ACCURACY :
# : 95.80454096742349

# %% [raw]
# <------------------------------------------ MODEL ACCURACY COMPARISON ------------------------------------------------------->

# %%
x_axis = ['Random Forest','Naive Bayes','KNN','Kernel SVM','SVM','Logistic Regression','Decision Tree Algorithm']
y_axis = [ac7,ac6,ac5,ac4,ac3,ac2,ac1] 
plt.figure(figsize = (15,5))
plt.title('MODEL COMPARISON\n', fontweight='bold', color='orange')
plt.scatter(x_axis, y_axis, color='magenta', s=100, marker='X')
plt.grid(color = 'blue')
plt.show()

# %% [raw]
# Since Random Forest Classifier gave us the best results in terms of accuracy, we select RANDOM FOREST CLASSIFIER as our final algorithm
